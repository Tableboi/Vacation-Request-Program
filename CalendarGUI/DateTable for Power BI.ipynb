# %%
import pandas as pd
start= '1/1/2020'
end = '12/31/2020'
df= pd.DataFrame(pd.date_range(start,end,freq="H",tz='EST'),columns =['Datetime'])
df['LocaleTime'] = df["Datetime"].dt.strftime('%c')
df['Day'] =df["Datetime"].dt.day
df['Month'] = df["Datetime"].dt.month
df['Year'] = df["Datetime"].dt.year
df['time'] =df["Datetime"].dt.time
df['timezone'] =df["Datetime"].dt.tz
df['Hour'] =df["Datetime"].dt.hour
df['Quarter'] =df["Datetime"].dt.quarter
df['MonthName'] = df["Datetime"].dt.strftime('%b')
df['Week Name'] = df["Datetime"].dt.strftime('%A')
df['WeekNumber'] = df["Datetime"].dt.strftime('%W')
df['Weekday'] = df["Datetime"].dt.weekday
df['TimeofDay'] = df["Datetime"].dt.strftime('%p')
df['UTC_offset'] = df["Datetime"].dt.strftime('%z')
df['DayofYEar'] = df["Datetime"].dt.dayofyear
df['Century'] = df["Datetime"].dt.strftime('%Y')

# %%
df
# Out:
#                       Datetime                LocaleTime  Day  Month  Year  \
# 0    2020-01-01 00:00:00-05:00  Wed Jan  1 00:00:00 2020    1      1  2020
# 1    2020-01-01 01:00:00-05:00  Wed Jan  1 01:00:00 2020    1      1  2020
# 2    2020-01-01 02:00:00-05:00  Wed Jan  1 02:00:00 2020    1      1  2020
# 3    2020-01-01 03:00:00-05:00  Wed Jan  1 03:00:00 2020    1      1  2020
# 4    2020-01-01 04:00:00-05:00  Wed Jan  1 04:00:00 2020    1      1  2020
# ...                        ...                       ...  ...    ...   ...
# 8756 2020-12-30 20:00:00-05:00  Wed Dec 30 20:00:00 2020   30     12  2020
# 8757 2020-12-30 21:00:00-05:00  Wed Dec 30 21:00:00 2020   30     12  2020
# 8758 2020-12-30 22:00:00-05:00  Wed Dec 30 22:00:00 2020   30     12  2020
# 8759 2020-12-30 23:00:00-05:00  Wed Dec 30 23:00:00 2020   30     12  2020
# 8760 2020-12-31 00:00:00-05:00  Thu Dec 31 00:00:00 2020   31     12  2020
#
#           time timezone  Hour  Quarter MonthName  Week Name WeekNumber  \
# 0     00:00:00      EST     0        1       Jan  Wednesday         00
# 1     01:00:00      EST     1        1       Jan  Wednesday         00
# 2     02:00:00      EST     2        1       Jan  Wednesday         00
# 3     03:00:00      EST     3        1       Jan  Wednesday         00
# 4     04:00:00      EST     4        1       Jan  Wednesday         00
# ...        ...      ...   ...      ...       ...        ...        ...
# 8756  20:00:00      EST    20        4       Dec  Wednesday         52
# 8757  21:00:00      EST    21        4       Dec  Wednesday         52
# 8758  22:00:00      EST    22        4       Dec  Wednesday         52
# 8759  23:00:00      EST    23        4       Dec  Wednesday         52
# 8760  00:00:00      EST     0        4       Dec   Thursday         52
#
#       Weekday TimeofDay UTC_offset  DayofYEar Century
# 0           2        AM      -0500          1    2020
# 1           2        AM      -0500          1    2020
# 2           2        AM      -0500          1    2020
# 3           2        AM      -0500          1    2020
# 4           2        AM      -0500          1    2020
# ...       ...       ...        ...        ...     ...
# 8756        2        PM      -0500        365    2020
# 8757        2        PM      -0500        365    2020
# 8758        2        PM      -0500        365    2020
# 8759        2        PM      -0500        365    2020
# 8760        3        AM      -0500        366    2020
#
# [8761 rows x 17 columns]
